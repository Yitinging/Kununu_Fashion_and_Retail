# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Kununu data
df = pd.read_csv('/content/drive/MyDrive/kununu_competitors.csv')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                             user_uuid  \
# 0            20          20  7ea80496-23b9-4164-985c-7b477723589e
# 1           128         128  0cb44bd1-0104-445c-a975-b99c45001781
# 2           169         169  8684b74f-072e-4878-9ef1-a0ac9329e1f6
# 3           326         326  640a8bfc-3789-4239-bb0f-ccb24da465fd
# 4           376         376  3f69170d-2dc0-43c1-a196-7356f7ed1021
#
#                    company_name                          profile_uuid  \
# 0             Robert Bosch GmbH  39f1ca5c-8321-4d18-85d6-3924e3a43e65
# 1   Dr. Ing. h.c. F. Porsche AG  dd9996e3-17dd-4a87-ae39-c71de1482922
# 2                  Bosch Gruppe  39f1ca5c-8321-4d18-85d6-3924e3a43e65
# 3       Bosch Solarthermie GmbH  39f1ca5c-8321-4d18-85d6-3924e3a43e65
# 4  Bosch Packaging Systems GmbH  39f1ca5c-8321-4d18-85d6-3924e3a43e65
#
#                   profile_name            profile_city  \
# 0                 Bosch Gruppe               Stuttgart
# 1  Dr. Ing. h.c. F. Porsche AG  Stuttgart-Zuffenhausen
# 2                 Bosch Gruppe               Stuttgart
# 3                 Bosch Gruppe               Stuttgart
# 4                 Bosch Gruppe               Stuttgart
#
#   profile_industry_name_en                          company_uuid  \
# 0            Manufacturing  ada79380-3879-4010-aaa6-05ad898767f1
# 1               Automotive  ac97887a-10e4-4579-9143-74a0258b604c
# 2            Manufacturing  1473843b-47fe-43cf-96d3-b05ac8bc8f5e
# 3            Manufacturing  8eba49ea-8dfc-4eca-b32f-836b5cb65b89
# 4            Manufacturing  d60ff3d8-522d-43cb-ad63-74a7f804a820
#
#             company_city  ... pension_plan clothes daycare  reachability  \
# 0              Stuttgart  ...         True     NaN    True          True
# 1              Stuttgart  ...         True     NaN    True          True
# 2  Ottobrunn bei München  ...         True     NaN     NaN           NaN
# 3             Wettringen  ...         True     NaN     NaN          True
# 4             Remshalden  ...          NaN     NaN     NaN          True
#
#    coaching                   feedback_suggestion_text  \
# 0      True                                        NaN
# 1      True                                        NaN
# 2      True                                        NaN
# 3       NaN                     Mhh... Soll so bleiben
# 4       NaN  Mehr Flexibilität und Kundenorientierung.
#
#                               feedback_positive_text  feedback_negative_text  \
# 0  Faires Unternehmen, gute Konditionen, tolle Ge...                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                Die tollen Kollegen, ein super Team                     Nix
# 4                                                NaN                     NaN
#
#                                      profile_url  company_name_short
# 0        https://www.kununu.com/de/bosch-gruppe2               Bosch
# 1  https://www.kununu.com/de/dr-ing-hc-f-porsche             Porsche
# 2        https://www.kununu.com/de/bosch-gruppe2               Bosch
# 3        https://www.kununu.com/de/bosch-gruppe2               Bosch
# 4        https://www.kununu.com/de/bosch-gruppe2               Bosch
#
# [5 rows x 72 columns]

# %%
# extracted data
df_lv = pd.read_csv('/content/drive/MyDrive/Fully_Updated_LVMH_Reviews.csv')
df_lv.head(10)
# Out:
#             Date  Rating                   Review Title  \
# 0  20. Jan. 2024     5.0  Work student business analyst
# 1   9. Feb. 2022     3.0           Room for improvement
# 2   12 Feb. 2020     4.0                            gut
# 3  11 Sept. 2024     5.0                Payroll Manager
# 4   31 Aug. 2024     5.0                            Top
# 5   22 Aug. 2024     4.0            Feedback Internship
# 6   30 July 2024     5.0                Best Experience
# 7    2 July 2024     4.0             Experience at LVMH
# 8    5 June 2024     4.0               Interesting Work
# 9    13 May 2024     5.0                   Good Company
#
#                       Topic/Job Role  \
# 0  Work student business development
# 1        Customer service specialist
# 2                  Beauty Consultant
# 3                    Payroll Manager
# 4                                CDP
# 5                 Stage Data Analyst
# 6               Data Engineer Intern
# 7              Supply Chain Engineer
# 8           Customer Care Specialist
# 9                         Operations
#
#                                          Good Points  \
# 0             Flexible working hours and good salary
# 1  Family-like atmosphere, not too much pressure ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                           Bad Points           Location  \
# 0  No Christmas money and extra money for essentials  Frankfurt am Main
# 1  Lack of ambition and lack of means to do bette...  Frankfurt am Main
# 2                                                NaN  Frankfurt am Main
# 3                                                NaN              Paris
# 4                                                NaN              Paris
# 5                                                NaN              Paris
# 6                                                NaN  Neuilly-sur-Seine
# 7                                                NaN             Clichy
# 8                                                NaN              Paris
# 9                                                NaN   Levallois-Perret
#
#                             Good Points (Translated)  \
# 0            Flexible Arbeitszeiten und gutes Gehalt
# 1  Familiäre Atmosphäre, nicht zu viel Druck bei ...
# 2  Gesamt Bewertung Eindruck bei Benefit LVMH war...
# 3  Participation, salary reductions, group produc...
# 4           Everything and a very good works council
# 5  Environment and interesting topics, internatio...
# 6  The manager is attentive, the atmosphere is pl...
# 7    Prestige, renown, easy to find a job afterwards
# 8       Interesting work, bonuses, social advantages
# 9                             Very nice headquarters
#
#                              Bad Points (Translated)
# 0  Kein Weihnachtsgeld und kein zusätzliches Geld...
# 1  Mangel an Ehrgeiz und fehlende Mittel für bess...
# 2                 Kollengenzusammenhalt: Mangelhaft.
# 3        Lack of cohesion with other group companies
# 4                 Nothing else other than the coffee
# 5                              High workload, salary
# 6                        For me, I see no drawbacks.
# 7                       Low salary, external factors
# 8                      No pressure, no work overload
# 9                       Lots of turnover in services

# %%
df_rl = pd.read_csv('/content/drive/MyDrive/rl_reviews_fully_complete.csv')
df_rl.head()
# Out:
#             Date  Rating                                              Title  \
# 0  19. Okt. 2017     5.0                                         Internship
# 1  13. März 2024     4.0                                      Allgemein gut
# 2  21. Feb. 2023     3.0  Machbare Aufgaben wenn die Kommunikation funkt...
# 3   8. Apr. 2022     3.0                                                Gut
# 4   8. Feb. 2021     3.0                  Macht sich gut auf dem Lebenslauf
#
#                      Job Role         Location  \
# 0                      Intern  München, Bayern
# 1            Retail assistant  München, Bayern
# 2  Sales operations associate  München, Bayern
# 3  Sales operations associate  München, Bayern
# 4               Praktikant/in  München, Bayern
#
#                                          Good Points  \
# 0    gutes Klimas - Junges Team - Tolles Unternehmen
# 1                       Meisten Leute here sind nett
# 2  kollegiales Zusammensein - moderates Gehalt fü...
# 3  Schöne Marke, schöne Büros, Rabatt für Mitarbe...
# 4           Großes Unternehmen, Viele interne Events
#
#                                           Bad Points
# 0               alles Super und angenehmes arbeiten!
# 1                        Gehalt kann noch höher sein
# 2  sehr schlechte Einarbeitung durch Probleme mit...
# 3       Kommunikation und Training können verbessern
# 4  Inkompetente Vorgesetzte, man kann leicht ausg...

# %%
good_points = df_lv[['Good Points (Translated)']].rename(columns={'Good Points (Translated)': 'feedback_suggestion_text'})
bad_points = df_lv[['Bad Points (Translated)']].rename(columns={'Bad Points (Translated)': 'feedback_suggestion_text'})

df_stacked = pd.concat([good_points, bad_points], axis=0).reset_index(drop=True)

df_stacked['company_name_short'] = 'LVMH'

print(df_stacked.head())
# Out:
#                             feedback_suggestion_text company_name_short
# 0            Flexible Arbeitszeiten und gutes Gehalt               LVMH
# 1  Familiäre Atmosphäre, nicht zu viel Druck bei ...               LVMH
# 2  Gesamt Bewertung Eindruck bei Benefit LVMH war...               LVMH
# 3  Participation, salary reductions, group produc...               LVMH
# 4           Everything and a very good works council               LVMH

# %%
good_points = df_rl[['Good Points']].rename(columns={'Good Points': 'feedback_suggestion_text'})
bad_points = df_lv[['Bad Points']].rename(columns={'Bad Points': 'feedback_suggestion_text'})

df_stacked_2 = pd.concat([good_points, bad_points], axis=0).reset_index(drop=True)
df_stacked_2['company_name_short'] = 'Ralph Lauren'

print(df_stacked_2.head())
# Out:
#                             feedback_suggestion_text company_name_short
# 0    gutes Klimas - Junges Team - Tolles Unternehmen       Ralph Lauren
# 1                       Meisten Leute here sind nett       Ralph Lauren
# 2  kollegiales Zusammensein - moderates Gehalt fü...       Ralph Lauren
# 3  Schöne Marke, schöne Büros, Rabatt für Mitarbe...       Ralph Lauren
# 4           Großes Unternehmen, Viele interne Events       Ralph Lauren

# %%
df_stacked = pd.concat([df_stacked, df_stacked_2], axis=0).reset_index(drop=True)

# %%
other_columns = [col for col in df.columns if col not in ['feedback_suggestion_text', 'company_name_short']]
for col in other_columns:
    df_stacked[col] = None

df_stacked = df_stacked[df.columns]

df = pd.concat([df, df_stacked], axis=0, ignore_index=True)
# Out:
# <ipython-input-9-9a10618ea303>:7: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df_stacked], axis=0, ignore_index=True)

# %%
# Review statistics
def review_statistics(df, review_cols):

    company_stats = {}


    grouped = df.groupby('company_name_short')[review_cols]

    for company, group in grouped:

        total_reviews = 0
        word_lengths = []


        for col in review_cols:
            non_null_reviews = group[col].dropna()
            total_reviews += len(non_null_reviews)


            word_lengths += non_null_reviews.apply(lambda x: len(str(x).split())).tolist()


        if word_lengths:
            max_length = max(word_lengths)
            min_length = min(word_lengths)
            mean_length = sum(word_lengths) / len(word_lengths)
        else:
            max_length = min_length = mean_length = 0


        company_stats[company] = {
            'total_reviews': total_reviews,
            'max_length': max_length,
            'min_length': min_length,
            'mean_length': mean_length
        }


    stats_df = pd.DataFrame(company_stats).T
    return stats_df


review_cols = [
    "employer_atmosphere_score_text", "employer_communication_score_text", "employer_teamwork_score_text",
    "employer_work_life_score_text", "employer_leadership_score_text", "employer_tasks_score_text",
    "employer_equality_score_text", "employer_old_colleagues_score_text", "employer_work_conditions_score_text",
    "employer_environment_score_text", "employer_salary_score_text", "employer_image_score_text",
    "employer_career_score_text", "feedback_suggestion_text", "feedback_positive_text", "feedback_negative_text"
]
df_review_stats = review_statistics(df, review_cols)
print(df_review_stats)
# Out:
#                 total_reviews  max_length  min_length  mean_length
# Adidas                 1967.0       145.0         1.0    12.418404
# Bosch                 14406.0       194.0         1.0    13.444468
# Burberry                 46.0       171.0         1.0    21.586957
# Giorgio Armani           28.0        23.0         1.0     7.357143
# Hugo Boss              1492.0       366.0         1.0    18.025469
# LVMH                    604.0       165.0         1.0    15.241722
# Marc O'Polo             584.0       176.0         1.0    17.551370
# Mercedes-Benz          4660.0       192.0         1.0    14.742918
# PVH                     649.0       185.0         1.0    15.548536
# Porsche               10949.0       193.0         1.0    17.138460
# Ralph Lauren            202.0        60.0         1.0    10.262376

# %%
reviews_list = []


for col in review_cols:

    temp_df = df[['company_name_short', col]].dropna()


    temp_df = temp_df.rename(columns={col: 'review'})


    reviews_list.append(temp_df)


df_reviews = pd.concat(reviews_list, ignore_index=True)


print(df_reviews.head(10))
# Out:
#   company_name_short                                             review
# 0            Porsche         Gutes Team, Flexibel auch wegen HomeOffice
# 1          Hugo Boss  Eine entspannte Arbeitsatmosphäre, nette Kolle...
# 2              Bosch  Tolle Kollegen, freundliche art der Zusammenar...
# 3                PVH  Absolut abhängig vom Store Team selbst, in den...
# 4              Bosch  Nichts zu beanstanden, hilfsbereite Teamleiter...
# 5          Hugo Boss  HB ist ein toller Arbeitgeber mit einer offene...
# 6            Porsche  Ich möchte besonders das super Betriebsklima h...
# 7             Adidas  People who can not lead were promoted in posit...
# 8              Bosch  manchmal sehr angespannt und stressig. Alle Ko...
# 9              Bosch  Angenehm. Kein starres Führen, kein Micromanag...

# %%
pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.10/dist-packages (0.16.3)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.8.38.post1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (3.1.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (0.5.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.4.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (10.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2024.6.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers>=0.4.1->bertopic) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers>=0.4.1->bertopic) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
# Train topic modelling to find topic among all the reviews
from bertopic import BERTopic


def bert_topic_modeling(df):

    all_reviews = df['review'].dropna().tolist()


    topic_model = BERTopic(language="german")


    topics, probs = topic_model.fit_transform(all_reviews)

    return topic_model, topics, probs


topic_model, topics, probs = bert_topic_modeling(df_reviews)


print(topic_model.get_topic_info())
# Out:
#      Topic  Count                                               Name  \
# 0       -1  13971                         -1_man_die_und_mitarbeiter
# 1        0   1106          0_überstunden_arbeitszeiten_stunden_woche
# 2        1   1046         1_team_teams_zusammenhalt_teamzusammenhalt
# 3        2    818                    2_ältere_älteren_kollegen_alter
# 4        3    720                          3_bosch_robert_gmbh_werte
# ..     ...    ...                                                ...
# 391    390     10                390_meckern_niveau_hohem_besonderen
# 392    391     10                  391_fuhrpark_siehe_schippe_schaue
# 393    392     10  392_management_entscheidungsfreiraum_gezüchtet...
# 394    393     10      393_personenabhängig_abhängig_person_personen
# 395    394     10     394_parasit_revoluzzer_weitergebracht_verliebt
#
#                                         Representation  \
# 0    [man, die, und, mitarbeiter, nicht, der, es, z...
# 1    [überstunden, arbeitszeiten, stunden, woche, f...
# 2    [team, teams, zusammenhalt, teamzusammenhalt, ...
# 3    [ältere, älteren, kollegen, alter, junge, jung...
# 4    [bosch, robert, gmbh, werte, bei, we, image, h...
# ..                                                 ...
# 391  [meckern, niveau, hohem, besonderen, hindernis...
# 392  [fuhrpark, siehe, schippe, schaue, hinsehen, z...
# 393  [management, entscheidungsfreiraum, gezüchtet,...
# 394  [personenabhängig, abhängig, person, personen,...
# 395  [parasit, revoluzzer, weitergebracht, verliebt...
#
#                                    Representative_Docs
# 0    [Arbeitnehmer ernst nehmen und auf Augenhöhe b...
# 1    [flexible Arbeitszeiten, Sehr flexible Arbeits...
# 2             [Super team, Im Team sehr gut, Ein Team]
# 3    [Ältere Kollegen werden geschätzt., Es gibt we...
# 4    [Siehe Robert Bosch und die Robert Bosch Stift...
# ..                                                 ...
# 391  [Nichts, meckern auf hohem Niveau, Nichts im B...
# 392  [siehe Punkte oben, Man schaue sich einfach de...
# 393  [Teilweise werden diese im Mittleren-Managemen...
# 394  [Wie überall Personenabhängig, Personenabhängi...
# 395  [im Service Jung und Dumm und im Verkauf selbs...
#
# [396 rows x 5 columns]

# %%
print(topic_model.get_topic_info()[:11])
# Out:
#     Topic  Count                                               Name  \
# 0      -1  13971                         -1_man_die_und_mitarbeiter
# 1       0   1106          0_überstunden_arbeitszeiten_stunden_woche
# 2       1   1046         1_team_teams_zusammenhalt_teamzusammenhalt
# 3       2    818                    2_ältere_älteren_kollegen_alter
# 4       3    720                          3_bosch_robert_gmbh_werte
# 5       4    585            4_frauen_männer_frau_führungspositionen
# 6       5    533             5_büros_großraumbüros_büro_ausstattung
# 7       6    490  6_führungskräfte_führung_führungskraft_vorgese...
# 8       7    476                    7_porsche_ag_leipzig_consulting
# 9       8    359         8_kollegen_nette_zusammenhalt_hilfsbereite
# 10      9    286        9_gehalt_gehälter_gehaltserhöhung_bezahlung
#
#                                        Representation  \
# 0   [man, die, und, mitarbeiter, nicht, der, es, z...
# 1   [überstunden, arbeitszeiten, stunden, woche, f...
# 2   [team, teams, zusammenhalt, teamzusammenhalt, ...
# 3   [ältere, älteren, kollegen, alter, junge, jung...
# 4   [bosch, robert, gmbh, werte, bei, we, image, h...
# 5   [frauen, männer, frau, führungspositionen, fra...
# 6   [büros, großraumbüros, büro, ausstattung, groß...
# 7   [führungskräfte, führung, führungskraft, vorge...
# 8   [porsche, ag, leipzig, consulting, marke, imag...
# 9   [kollegen, nette, zusammenhalt, hilfsbereite, ...
# 10  [gehalt, gehälter, gehaltserhöhung, bezahlung,...
#
#                                   Representative_Docs
# 0   [Arbeitnehmer ernst nehmen und auf Augenhöhe b...
# 1   [flexible Arbeitszeiten, Sehr flexible Arbeits...
# 2            [Super team, Im Team sehr gut, Ein Team]
# 3   [Ältere Kollegen werden geschätzt., Es gibt we...
# 4   [Siehe Robert Bosch und die Robert Bosch Stift...
# 5   [Viele Frauen in Führungspositionen., Zwischen...
# 6   [Top moderne Ausstattung. Ergonomische Arbeits...
# 7   [Die meisten Führungskräfte ,,führen“ über dru...
# 8        [Porsche, Porsche...., Porsche ist Porsche.]
# 9   [Nette Kollegen, wenig zusammenhalt, Nette, hi...
# 10  [Sozialleistungen werden von der Firma gute An...

# %%
df_reviews['topic'] = topics
df_reviews['prob'] = probs

# %%
df_reviews
# Out:
#       company_name_short                                             review  \
# 0                Porsche         Gutes Team, Flexibel auch wegen HomeOffice
# 1              Hugo Boss  Eine entspannte Arbeitsatmosphäre, nette Kolle...
# 2                  Bosch  Tolle Kollegen, freundliche art der Zusammenar...
# 3                    PVH  Absolut abhängig vom Store Team selbst, in den...
# 4                  Bosch  Nichts zu beanstanden, hilfsbereite Teamleiter...
# ...                  ...                                                ...
# 35582            Porsche  alte Männer in Führungspositionen die tw. noch...
# 35583              Bosch                                      keine Kantine
# 35584              Bosch                                      alles geheim!
# 35585            Porsche  Mitunter sehr abhängig vom Team, wie Kultur, Z...
# 35586              Bosch                    fällt mir gerade nichts ein :-)
#
#        topic      prob
# 0          1  1.000000
# 1         -1  0.000000
# 2          8  1.000000
# 3          1  0.993640
# 4          1  0.763273
# ...      ...       ...
# 35582      2  1.000000
# 35583    108  0.205116
# 35584     79  0.430301
# 35585      1  0.761331
# 35586     11  0.972083
#
# [35587 rows x 4 columns]

# %%
topics_of_interest = [0, 1, 2, 4, 6, 9]
filtered_reviews = df_reviews[df_reviews['topic'].isin(topics_of_interest)]


print(filtered_reviews)
# Out:
#       company_name_short                                             review  \
# 0                Porsche         Gutes Team, Flexibel auch wegen HomeOffice
# 2                  Bosch  Tolle Kollegen, freundliche art der Zusammenar...
# 3                    PVH  Absolut abhängig vom Store Team selbst, in den...
# 4                  Bosch  Nichts zu beanstanden, hilfsbereite Teamleiter...
# 7                 Adidas  People who can not lead were promoted in posit...
# ...                  ...                                                ...
# 35564              Bosch  Etwas patriarchalisches System der Entwicklung...
# 35572              Bosch  Die Vorgesetzten. Handeln nur zu ihrem eigenen...
# 35575            Porsche  Es gab teilweise auch wirklich Wochen, wo die ...
# 35582            Porsche  alte Männer in Führungspositionen die tw. noch...
# 35585            Porsche  Mitunter sehr abhängig vom Team, wie Kultur, Z...
#
#        topic      prob
# 0          1  1.000000
# 2          8  1.000000
# 3          1  0.993640
# 4          1  0.763273
# 7          6  0.960249
# ...      ...       ...
# 35564      4  0.861034
# 35572      6  0.823281
# 35575      0  1.000000
# 35582      2  1.000000
# 35585      1  0.761331
#
# [5223 rows x 4 columns]

# %%
# Translate into English to get better result for Sentimental Analysis
import torch
from transformers import MarianMTModel, MarianTokenizer


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


translation_model = MarianMTModel.from_pretrained('Helsinki-NLP/opus-mt-de-en').to(device)
translation_tokenizer = MarianTokenizer.from_pretrained('Helsinki-NLP/opus-mt-de-en')


def translate_to_english(text):

    inputs = translation_tokenizer(text, return_tensors="pt", padding=True).to(device)


    translated = translation_model.generate(**inputs)


    return translation_tokenizer.decode(translated[0], skip_special_tokens=True)




filtered_reviews['review_en'] = filtered_reviews['review'].apply(translate_to_english)

# %%
# Sentimental Analysis
from transformers import pipeline
import torch


device = 0 if torch.cuda.is_available() else -1


sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english", device=device)


def analyze_sentiment(review_en):

    result = sentiment_analyzer(review_en)[0]


    if result['label'] == 'POSITIVE':
        return 1  # Positive
    else:
        return 0  # Negative or neutral (treat neutral as negative in this case)


filtered_reviews['sentiment'] = filtered_reviews['review_en'].apply(analyze_sentiment)


print(filtered_reviews.head())
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   company_name_short                                             review  \
# 0            Porsche         Gutes Team, Flexibel auch wegen HomeOffice
# 2              Bosch  Tolle Kollegen, freundliche art der Zusammenar...
# 3                PVH  Absolut abhängig vom Store Team selbst, in den...
# 4              Bosch  Nichts zu beanstanden, hilfsbereite Teamleiter...
# 7             Adidas  People who can not lead were promoted in posit...
#
#    topic      prob                                          review_en  \
# 0      1  1.000000     Good team, flexible also because of HomeOffice
# 2      8  1.000000  Great colleagues, friendly way of working toge...
# 3      1  0.993640  Absolutely dependent on the store team itself,...
# 4      1  0.763273  Nothing to complain about, helpful team leader...
# 7      6  0.960249  People who can not lead were promoted in posit...
#
#    sentiment
# 0          1
# 2          1
# 3          1
# 4          1
# 7          0

# %%
topic_mapping = {
    0: "arbeitszeiten_überstunden",
    1: "teams_zusammenhalt",
    2: "älteren_kollegen_junge",
    4: "frau_männer_führungspositionen",
    6: "führungskräfte_führungskompetenz",   
    9: "gehaltserhöhung_bezahlung"
}

filtered_reviews['topic_name'] = filtered_reviews['topic'].map(topic_mapping)
filtered_reviews = filtered_reviews.dropna(subset=['topic_name'])

print(filtered_reviews.head())
# Out:
#   company_name_short                                             review  \
# 0            Porsche         Gutes Team, Flexibel auch wegen HomeOffice
# 1                PVH  Absolut abhängig vom Store Team selbst, in den...
# 2              Bosch  Nichts zu beanstanden, hilfsbereite Teamleiter...
# 3             Adidas  People who can not lead were promoted in posit...
# 4              Bosch                        Tolles internationales Team
#
#    topic      prob                                          review_en  \
# 0      1  1.000000     Good team, flexible also because of HomeOffice
# 1      1  0.993640  Absolutely dependent on the store team itself,...
# 2      1  0.763273  Nothing to complain about, helpful team leader...
# 3      6  0.960249  People who can not lead were promoted in posit...
# 4      1  0.893744                           Great international team
#
#    sentiment                        topic_name
# 0          1                teams_zusammenhalt
# 1          1                teams_zusammenhalt
# 2          1                teams_zusammenhalt
# 3          0  führungskräfte_führungskompetenz
# 4          1                teams_zusammenhalt

# %%
import pandas as pd
from google.colab import files


file_path = 'filtered_reviews.csv'
filtered_reviews.to_csv(file_path, index=False, encoding='utf-8')


files.download(file_path)

# %%
topic_counts = filtered_reviews.groupby(['company_name_short', 'topic']).size().reset_index(name='review_count')
pd.set_option('display.max_rows', None)

print(topic_counts)
# Out:
#    company_name_short  topic  review_count
# 0              Adidas      0            50
# 1              Adidas      1            59
# 2              Adidas      2            60
# 3              Adidas      4            22
# 4              Adidas      6            36
# 5              Adidas      9            18
# 6               Bosch      0           452
# 7               Bosch      1           328
# 8               Bosch      2           326
# 9               Bosch      4           231
# 10              Bosch      6           154
# 11              Bosch      9            84
# 12           Burberry      0             1
# 13           Burberry      1             5
# 14           Burberry      2             1
# 15           Burberry      6             1
# 16     Giorgio Armani      1             1
# 17     Giorgio Armani      2             1
# 18     Giorgio Armani      6             1
# 19          Hugo Boss      0            46
# 20          Hugo Boss      1            46
# 21          Hugo Boss      2            33
# 22          Hugo Boss      4            28
# 23          Hugo Boss      6            39
# 24          Hugo Boss      9            14
# 25               LVMH      0            21
# 26               LVMH      1            34
# 27               LVMH      2             9
# 28               LVMH      4             5
# 29               LVMH      6             7
# 30               LVMH      9            10
# 31        Marc O'Polo      0            16
# 32        Marc O'Polo      1            20
# 33        Marc O'Polo      2             8
# 34        Marc O'Polo      4             6
# 35        Marc O'Polo      6            18
# 36        Marc O'Polo      9            12
# 37      Mercedes-Benz      0           122
# 38      Mercedes-Benz      1           156
# 39      Mercedes-Benz      2           107
# 40      Mercedes-Benz      4            77
# 41      Mercedes-Benz      6            82
# 42      Mercedes-Benz      9            35
# 43                PVH      0            35
# 44                PVH      1            23
# 45                PVH      2            13
# 46                PVH      4             6
# 47                PVH      6             7
# 48                PVH      9             8
# 49            Porsche      0           356
# 50            Porsche      1           361
# 51            Porsche      2           257
# 52            Porsche      4           209
# 53            Porsche      6           142
# 54            Porsche      9           101
# 55       Ralph Lauren      0             7
# 56       Ralph Lauren      1            13
# 57       Ralph Lauren      2             3
# 58       Ralph Lauren      4             1
# 59       Ralph Lauren      6             3
# 60       Ralph Lauren      9             4

# %%
results = []


for company in filtered_reviews['company_name_short'].unique():

    company_reviews = filtered_reviews[filtered_reviews['company_name_short'] == company]


    for topic in company_reviews['topic_name'].unique():

        topic_reviews = company_reviews[company_reviews['topic_name'] == topic]


        positive_rate = topic_reviews['sentiment'].mean()


        results.append({
            'company_name_short': company,
            'topic_name': topic,
            'positive_rate': positive_rate
        })


positive_rate_df = pd.DataFrame(results)


print(positive_rate_df)
# Out:
#    company_name_short                        topic_name  positive_rate
# 0             Porsche                teams_zusammenhalt       0.867036
# 1             Porsche  führungskräfte_führungskompetenz       0.126761
# 2             Porsche         arbeitszeiten_überstunden       0.477528
# 3             Porsche         gehaltserhöhung_bezahlung       0.128713
# 4             Porsche            älteren_kollegen_junge       0.571984
# 5             Porsche    frau_männer_führungspositionen       0.516746
# 6                 PVH                teams_zusammenhalt       0.869565
# 7                 PVH            älteren_kollegen_junge       0.307692
# 8                 PVH         arbeitszeiten_überstunden       0.285714
# 9                 PVH  führungskräfte_führungskompetenz       0.000000
# 10                PVH    frau_männer_führungspositionen       0.500000
# 11                PVH         gehaltserhöhung_bezahlung       0.125000
# 12              Bosch                teams_zusammenhalt       0.841463
# 13              Bosch         arbeitszeiten_überstunden       0.575221
# 14              Bosch            älteren_kollegen_junge       0.539877
# 15              Bosch  führungskräfte_führungskompetenz       0.116883
# 16              Bosch    frau_männer_führungspositionen       0.432900
# 17              Bosch         gehaltserhöhung_bezahlung       0.130952
# 18             Adidas  führungskräfte_führungskompetenz       0.055556
# 19             Adidas            älteren_kollegen_junge       0.366667
# 20             Adidas                teams_zusammenhalt       0.762712
# 21             Adidas         arbeitszeiten_überstunden       0.500000
# 22             Adidas    frau_männer_führungspositionen       0.318182
# 23             Adidas         gehaltserhöhung_bezahlung       0.111111
# 24      Mercedes-Benz  führungskräfte_führungskompetenz       0.060976
# 25      Mercedes-Benz                teams_zusammenhalt       0.756410
# 26      Mercedes-Benz            älteren_kollegen_junge       0.523364
# 27      Mercedes-Benz         arbeitszeiten_überstunden       0.508197
# 28      Mercedes-Benz         gehaltserhöhung_bezahlung       0.085714
# 29      Mercedes-Benz    frau_männer_führungspositionen       0.441558
# 30        Marc O'Polo                teams_zusammenhalt       0.800000
# 31        Marc O'Polo  führungskräfte_führungskompetenz       0.055556
# 32        Marc O'Polo         arbeitszeiten_überstunden       0.125000
# 33        Marc O'Polo    frau_männer_führungspositionen       0.333333
# 34        Marc O'Polo            älteren_kollegen_junge       0.625000
# 35        Marc O'Polo         gehaltserhöhung_bezahlung       0.000000
# 36          Hugo Boss  führungskräfte_führungskompetenz       0.128205
# 37          Hugo Boss                teams_zusammenhalt       0.739130
# 38          Hugo Boss         arbeitszeiten_überstunden       0.391304
# 39          Hugo Boss    frau_männer_führungspositionen       0.464286
# 40          Hugo Boss         gehaltserhöhung_bezahlung       0.071429
# 41          Hugo Boss            älteren_kollegen_junge       0.545455
# 42     Giorgio Armani  führungskräfte_führungskompetenz       0.000000
# 43     Giorgio Armani                teams_zusammenhalt       1.000000
# 44     Giorgio Armani            älteren_kollegen_junge       0.000000
# 45           Burberry                teams_zusammenhalt       0.200000
# 46           Burberry  führungskräfte_führungskompetenz       1.000000
# 47           Burberry            älteren_kollegen_junge       1.000000
# 48           Burberry         arbeitszeiten_überstunden       0.000000
# 49               LVMH            älteren_kollegen_junge       0.666667
# 50               LVMH                teams_zusammenhalt       0.911765
# 51               LVMH         arbeitszeiten_überstunden       0.476190
# 52               LVMH  führungskräfte_führungskompetenz       0.000000
# 53               LVMH    frau_männer_führungspositionen       1.000000
# 54               LVMH         gehaltserhöhung_bezahlung       0.200000
# 55       Ralph Lauren            älteren_kollegen_junge       0.666667
# 56       Ralph Lauren         arbeitszeiten_überstunden       0.285714
# 57       Ralph Lauren  führungskräfte_führungskompetenz       0.333333
# 58       Ralph Lauren         gehaltserhöhung_bezahlung       0.500000
# 59       Ralph Lauren                teams_zusammenhalt       0.923077
# 60       Ralph Lauren    frau_männer_führungspositionen       1.000000

# %%
topic_order = positive_rate_df['topic_name'].unique()

positive_rate_df['topic_name'] = pd.Categorical(positive_rate_df['topic_name'], categories=topic_order, ordered=True)
plt.figure(figsize=(14, 8))


sns.lineplot(data=positive_rate_df[positive_rate_df['company_name_short'].isin([ 'Adidas','Bosch','Hugo Boss', 'Mercedes-Benz', 'Porsche', 'LVMH', 'LVMH'])], x='topic_name', y='positive_rate', hue='company_name_short', marker='o')


plt.title('Positive Rate by Topic and Company', fontsize=16)
plt.xlabel('Topic', fontsize=12)
plt.ylabel('Positive Rate', fontsize=12)
plt.axhline(y=0.6, color='red', linestyle='--', label='y=0.6')

plt.xticks(rotation=45)


plt.legend(title='Company')


plt.tight_layout()
plt.show()
# Out:
# c:\Users\yitin\miniconda3\envs\vitrual\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\yitin\miniconda3\envs\vitrual\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(14, 8))


sns.lineplot(data=positive_rate_df[positive_rate_df['company_name_short'] == 'Hugo Boss'], x='topic_name', y='positive_rate', marker='o')


plt.title('Positive Rate by Topic for Hugo Boss', fontsize=16)
plt.xlabel('Topic', fontsize=12)
plt.ylabel('Positive Rate', fontsize=12)
plt.axhline(y=0.6, color='red', linestyle='--', label='y=0.6')

plt.xticks(rotation=45)


plt.tight_layout()
plt.show()
# Out:
# c:\Users\yitin\miniconda3\envs\vitrual\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\yitin\miniconda3\envs\vitrual\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
