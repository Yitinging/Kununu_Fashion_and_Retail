# %%
import pandas as pd

# %%
df = pd.read_csv('Kununu_Fashion_and_Retail.csv')
df.head(5)
# Out:
#    Unnamed: 0                             user_uuid  \
# 0           0  f3521258-c82f-45a3-816b-644c9b4e56db
# 1           1  37599113-66f5-496f-842c-708991c503ef
# 2           2  62fa8e9f-d77c-4fe3-abe2-7732ae73de67
# 3           3  3755ac75-c33f-4a12-a7cf-c9ba04577f24
# 4           4  1e66365d-51ff-4735-b428-4b092f31cf83
#
#                   company_name                          profile_uuid  \
# 0      Schüco International KG  3b42dda1-4273-4170-ac6e-1d0de2f61986
# 1  iSi Automotive Austria GmbH  08a13af9-32f2-4200-a0f3-c6e086f3bbb4
# 2  Heinrich Huhn GmbH & Co. KG  df80615f-4272-458a-9dfc-6409feec335a
# 3  Komatsu Mining Germany GmbH  131ecf5e-1435-4c21-97bb-c6e1f4bdba9e
# 4     Gabler Werbeagentur GmbH  c7e107e6-10f0-47b3-9092-3d740a92b011
#
#                               profile_name profile_city  \
# 0                  Schüco International KG    Bielefeld
# 1              iSi Automotive Austria GmbH         Wien
# 2              Heinrich Huhn GmbH & Co. KG   Drolshagen
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365406 entries, 0 to 365405
# Data columns (total 70 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Unnamed: 0                           365406 non-null  int64
#  1   user_uuid                            365406 non-null  object
#  2   company_name                         365406 non-null  object
#  3   profile_uuid                         365406 non-null  object
#  4   profile_name                         365406 non-null  object
#  5   profile_city                         365403 non-null  object
#  6   profile_industry_name_en             365406 non-null  object
#  7   company_uuid                         365406 non-null  object
#  8   company_city                         342843 non-null  object
#  9   company_industry_name                365406 non-null  object
#  10  review_created_at                    365406 non-null  object
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# user_uuid                   object
# company_name                object
# profile_uuid                object
# profile_name                object
#                              ...
# coaching                    object
# feedback_suggestion_text    object
# feedback_positive_text      object
# feedback_negative_text      object
# profile_url                 object
# Length: 70, dtype: object

# %%
# Filter columns that contain the keyword 'text' and also keep 'company_name column'
filtered_columns = [col for col in df.columns if 'text' in col or col == 'company_name']

# Create a new DataFrame with only the filtered columns
df_new = df[filtered_columns]

# Convert all words in the 'company_name' column to lowercase
df_new['company_name'] = df_new['company_name'].str.lower()

df_new.head()
# Out:
# C:\Users\wuzhu\AppData\Local\Temp\ipykernel_72176\3768017937.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['company_name'] = df_new['company_name'].str.lower()
#                   company_name             employer_atmosphere_score_text  \
# 0      schüco international kg                                        NaN
# 1  isi automotive austria gmbh                                        NaN
# 2  heinrich huhn gmbh & co. kg  Es herrscht ständig Angst vor Entlassung.
# 3  komatsu mining germany gmbh                                        NaN
# 4     gabler werbeagentur gmbh          Gehe jeden Tag gerne zum Arbeiten
#
#   employer_communication_score_text          employer_teamwork_score_text  \
# ...

# %%
# Function to assign values based on company_name
def assign_company_name(row):
    if 'hugo boss' in row:
        return 'Hugo Boss'
    elif 'bosch' in row:
        return 'Bosch'
    elif 'adidas' in row:
        return 'Adidas'
    elif 'giorgio armani' in row:
        return 'Giorgio Armani'
    elif 'lvmh' in row:
        return 'LVMH'
    elif 'marc o' in row:
        return 'Marc O Polo'
    elif 'mercedes' in row:
        return 'Mercedes Benz'
    elif 'porsche' in row:
        return 'Porsche'
    elif 'pvh' in row:
        return 'PVH'
    elif 'ralph lauren' in row:
        return 'Ralph Lauren'
    else:
        return None



# Create a new column based on the company_name values
df_new['company_group'] = df_new['company_name'].apply(assign_company_name)

# Filter out rows where company_group is None
df_filtered = df_new[df_new['company_group'].notnull()]

# Display the filtered DataFrame
df_filtered
# Out:
# C:\Users\wuzhu\AppData\Local\Temp\ipykernel_72176\1530234142.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['company_group'] = df_new['company_name'].apply(assign_company_name)
#                         company_name employer_atmosphere_score_text  \
# 20                 robert bosch gmbh                            NaN
# 128      dr. ing. h.c. f. porsche ag                            NaN
# 169                     bosch gruppe                            NaN
# 326          bosch solarthermie gmbh                            NaN
# 376     bosch packaging systems gmbh                            NaN
# ...                              ...                            ...
# ...

# %%
unique_values = df_filtered['company_group'].unique()
unique_values
# Out:
# array(['Bosch', 'Porsche', 'Hugo Boss', 'Adidas', 'Marc O Polo', 'PVH',
#        'Mercedes Benz', 'Ralph Lauren', 'Giorgio Armani', 'LVMH'],
#       dtype=object)

# %%
# Group the data by company_group
grouped_df = df_filtered.groupby('company_group')

# Create a dictionary to store DataFrames for each group
group_dfs = {}

# Iterate over the groups and create a new DataFrame for each group
for name, group in grouped_df:
    group_dfs[name] = group.reset_index(drop=True)
    print(f"\nDataFrame for group: {name}")
    print(group_dfs)
# Out:
# DataFrame for group: Adidas
# {'Adidas':     company_name                     employer_atmosphere_score_text  \
# 0      adidas ag                                                NaN
# 1         adidas  People who can not lead were promoted in posit...
# 2      adidas ag                  Jeder ist sich selbst der nächste
# 3      adidas ag  Wenn man älter als 45 ist hat man nichts zu la...
# 4         adidas                                                NaN
# ..           ...                                                ...
# 607       adidas                                                NaN
# 608    adidas ag  Internationales Umfeld, viele junge Kollegen, ...
# 609       adidas                                                NaN
# 610    adidas ag                                                NaN
# 611       adidas                                      Sehr schlecht
#
#                      employer_communication_score_text  \
# ...

# %%
hugo_boss_df = group_dfs['Hugo Boss']
hugo_boss_df
# Out:
#                 company_name  \
# 0               hugo boss ag
# 1               hugo boss ag
# 2               hugo boss ag
# 3               hugo boss ag
# 4               hugo boss ag
# ..                       ...
# 411             hugo boss ag
# 412             hugo boss ag
# 413             hugo boss ag
# 414  hugo boss ag, metzingen
# 415             hugo boss ag
#
#                         employer_atmosphere_score_text  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Eine entspannte Arbeitsatmosphäre, nette Kolle...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 411                                                NaN
# 412                                                NaN
# 413                                                NaN
# ...

# %%
hugo_boss_df.columns
# Out:
# Index(['company_name', 'employer_atmosphere_score_text',
#        'employer_communication_score_text', 'employer_teamwork_score_text',
#        'employer_work_life_score_text', 'employer_leadership_score_text',
#        'employer_tasks_score_text', 'employer_equality_score_text',
#        'employer_old_colleagues_score_text',
#        'employer_work_conditions_score_text',
#        'employer_environment_score_text', 'employer_salary_score_text',
#        'employer_image_score_text', 'employer_career_score_text',
#        'feedback_suggestion_text', 'feedback_positive_text',
#        'feedback_negative_text', 'company_group'],
#       dtype='object')

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wuzhu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import spacy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords

# Load the SpaCy English and German language models
nlp_en = spacy.load('en_core_web_sm')
nlp_de = spacy.load('de_core_news_sm')

# Combine stopwords from both English and German
stop_words_en = set(stopwords.words('english'))  # English stopwords
stop_words_de = set(stopwords.words('german'))   # German stopwords
stop_words_de.update([
    'der', 'die', 'das', 'und', 'ist', 'war', 'sind', 'hat',
    'firma', 'unternehmen', 'arbeit', 'mitarbeiter', 'chef',
    'kollegen', 'team', 'abteilung', 'manager', 'führung', 
    'position','gut', 'schlecht', 'zufrieden', 'unzufrieden', 
    'denken', 'fühlen','immer', 'mehr', 'viele', 'gibt', 'oft',
    'leider', 'vorgesetzten', 'führungskräfte', 'management', 'hr',
    'zeit', 'oben', 'leute', 'kommt', 'geht', 'wurde','teams', 
    'bereich', 'mitarbeitern', 'besser', 'gute', 'tolle','gehe', 'wäre', 
    'wenig', 'super', 'einfach', 'wirklich', 'praktikanten', 'hugo boss',
    'ganz', 'teilweise', 'kaum','weniger','münchen', 'jahre', 'komplette', 
    'teils', 'personalabteilung', 'monate', 'lvmh', 'marc', 'o', 'polo', 'mercedes', 'benz', 'pvh', 
    'ralph', 'lauren', 'porsche', 'gehalt', 'arbeiten', 'zusammen', 'produkte', 
    'abteilungen', 'kommunikation', 'top', 'informationen', 'umgang', 'innerhalb', 
    'besser', 'schlecht', 'gutes', 'letztes', 'menschlichkeit', 'menschen','jahr','jahren','guten',
    'meisten', 'druck', 'betriebsrat', 'eigentlich', 'jedoch', 'seit', 'arbeitgeber',
    'allerdings','möchte', 'offene','tag'])
combined_stopwords = stop_words_en.union(stop_words_de)  # Combine English and German stopwords

# Function to clean and remove stopwords from text (English and German stopwords)
def clean_text(text):
    if pd.isna(text):  # Handle missing or NaN values
        return ''
    
    # Convert to lowercase, remove URLs, special characters, and numbers
    text = text.lower()
    text = re.sub(r'http\S+|www.\S+', '', text)  # Remove URLs
    text = re.sub(r'[^a-zA-ZäöüÄÖÜß\s]', '', text)  # Keep German umlauts, remove special characters
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    
    # Remove stopwords from both English and German lists
    text = ' '.join([word for word in text.split() if word not in combined_stopwords])
    
    return text

# Apply cleaning to relevant feedback columns in the dataframe `b_df`
columns_to_analyze = [
    'employer_atmosphere_score_text', 
    'employer_communication_score_text', 
    'employer_teamwork_score_text',
    'feedback_suggestion_text',
    'feedback_positive_text',
    'feedback_negative_text'
]

# Clean each feedback column and store in new columns
for col in columns_to_analyze:
    hugo_boss_df[col + '_cleaned'] = hugo_boss_df[col].apply(clean_text)

# Combine all feedback columns into a single column
hugo_boss_df['all_feedback_cleaned'] = hugo_boss_df[[
    'employer_atmosphere_score_text_cleaned', 
    'employer_communication_score_text_cleaned',
    'employer_teamwork_score_text_cleaned',
    'feedback_suggestion_text_cleaned',
    'feedback_positive_text_cleaned',
    'feedback_negative_text_cleaned'
]].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# Function to generate and display a word cloud for the combined feedback
def generate_wordcloud(text_data, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)
    
    # Plot the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=20)
    plt.axis('off')
    plt.show()

# Combine all the cleaned feedback into one string
combined_feedback = ' '.join(hugo_boss_df['all_feedback_cleaned'])

# Generate a word cloud for the combined feedback
generate_wordcloud(combined_feedback, 'Word Cloud for All Feedback')

# %%
import pandas as pd
import spacy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
from nltk.corpus import stopwords

# Load the SpaCy English and German language models
nlp_en = spacy.load('en_core_web_sm')
nlp_de = spacy.load('de_core_news_sm')

# Combine stopwords from both English and German
stop_words_en = set(stopwords.words('english'))  # English stopwords
stop_words_en.update(['lot', 'nothing', 'good', 'great', 'company', 'employee',
                      'people', 'intern', 'adidas', 'bosch','macht', 'mal', 'manchmal', 
                      'schon', 'neue'])
stop_words_de = set(stopwords.words('german'))   # German stopwords
stop_words_de.update([
    'der', 'die', 'das', 'und', 'ist', 'war', 'sind', 'hat',
    'firma', 'unternehmen', 'arbeit', 'mitarbeiter', 'chef',
    'kollegen', 'team', 'abteilung', 'manager', 'führung', 
    'position','gut', 'schlecht', 'zufrieden', 'unzufrieden', 
    'denken', 'fühlen','immer', 'mehr', 'viele', 'gibt', 'oft',
    'leider', 'vorgesetzten', 'führungskräfte', 'management', 'hr',
    'zeit', 'oben', 'leute', 'kommt', 'geht', 'wurde','teams', 
    'bereich', 'mitarbeitern', 'besser', 'gute', 'tolle','gehe', 'wäre', 
    'wenig', 'super', 'einfach', 'wirklich', 'praktikanten', 'hugo boss',
    'ganz', 'teilweise', 'kaum','weniger','münchen', 'jahre', 'komplette', 
    'teils', 'personalabteilung', 'monate', 'lvmh', 'marc', 'o', 'polo', 'mercedes', 'benz', 'pvh', 
    'ralph', 'lauren', 'porsche', 'gehalt', 'arbeiten', 'zusammen', 'produkte', 
    'abteilungen', 'kommunikation', 'top', 'informationen', 'umgang', 'innerhalb', 
    'besser', 'schlecht', 'gutes', 'letztes', 'menschlichkeit', 'menschen','jahr','jahren','guten',
    'meisten', 'druck', 'betriebsrat', 'eigentlich', 'jedoch', 'seit', 'arbeitgeber',
    'allerdings','möchte', 'offene','tag','möglichkeit','gesprächen'])
combined_stopwords = stop_words_en.union(stop_words_de)  # Combine English and German stopwords

# Function to clean and remove stopwords from text (English and German stopwords)
def clean_text(text):
    if pd.isna(text):  # Handle missing or NaN values
        return ''
    
    # Convert to lowercase, remove URLs, special characters, and numbers
    text = text.lower()
    text = re.sub(r'http\S+|www.\S+', '', text)  # Remove URLs
    text = re.sub(r'[^a-zA-ZäöüÄÖÜß\s]', '', text)  # Keep German umlauts, remove special characters
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    
    # Remove stopwords from both English and German lists
    text = ' '.join([word for word in text.split() if word not in combined_stopwords])
    
    return text

# Function to generate and display a word cloud for the combined feedback
def generate_wordcloud(text_data, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text_data)
    
    # Plot the word cloud
    plt.figure(figsize=(7, 3))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=20)
    plt.axis('off')
    plt.show()

# List of columns to analyze for each company
columns_to_analyze = [
    'employer_atmosphere_score_text', 
    'employer_communication_score_text', 
    'employer_teamwork_score_text',
    'feedback_suggestion_text',
    'feedback_positive_text',
    'feedback_negative_text'
]

# Iterate over each company in group_dfs
for company, df in group_dfs.items():
    print(f"Processing company: {company}")
    
    # Clean each feedback column and store in new columns
    for col in columns_to_analyze:
        if col in df.columns:
            df[col + '_cleaned'] = df[col].apply(clean_text)

    # Combine all feedback columns into a single column
    df['all_feedback_cleaned'] = df[[
        col + '_cleaned' for col in columns_to_analyze if col + '_cleaned' in df.columns
    ]].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

    # Combine all the cleaned feedback into one string
    combined_feedback = ' '.join(df['all_feedback_cleaned'])
    
    # Generate a word cloud for the current company
    generate_wordcloud(combined_feedback, f'Word Cloud for {company}')
# Out:
# Processing company: Adidas
# Processing company: Bosch
# Processing company: Giorgio Armani
# Processing company: Hugo Boss
# Processing company: LVMH
# Processing company: Marc O Polo
# Processing company: Mercedes Benz
# Processing company: PVH
# Processing company: Porsche
# Processing company: Ralph Lauren

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Function to calculate and display the most frequently used words for each company
def display_most_frequent_words(text_data, company, top_n=10):
    # Split the text into words (tokens)
    words = text_data.split()
    
    # Count word frequencies
    word_frequencies = Counter(words)
    
    # Get the top N most common words
    most_common_words = word_frequencies.most_common(top_n)
    
    # Display the top N most common words
    print(f"Top {top_n} most frequently used words for {company}:")
    for word, freq in most_common_words:
        print(f"{word}: {freq}")
    
    # Plot the top N words in a bar chart
    words, counts = zip(*most_common_words)
    plt.figure(figsize=(7, 3))
    plt.barh(words, counts, color='skyblue')
    plt.title(f"Top {top_n} Most Frequent Words for {company}")
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.show()
# Iterate over each company in the `group_dfs` dictionary
for company, df in group_dfs.items():
    print(f"Processing company: {company}")
    
    # Clean each feedback column and store in new columns
    for col in columns_to_analyze:
        if col in df.columns:
            df[col + '_cleaned'] = df[col].apply(clean_text)

    # Combine all feedback columns into a single column
    df['all_feedback_cleaned'] = df[[
        col + '_cleaned' for col in columns_to_analyze if col + '_cleaned' in df.columns
    ]].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

    # Combine all the cleaned feedback into one string for each company
    combined_feedback = ' '.join(df['all_feedback_cleaned'])
    
    # Display the most frequent words for each company
    display_most_frequent_words(combined_feedback, company, top_n=10)
# Out:
# Processing company: Adidas
# Top 10 most frequently used words for Adidas:
# campus: 58
# work: 44
# working: 36
# communication: 29
# environment: 29
# culture: 27
# employees: 23
# flexible: 23
# atmosphere: 22
# balance: 22
# Processing company: Bosch
# Top 10 most frequently used words for Bosch:
# aufgaben: 183
# bezahlung: 157
# zusammenhalt: 151
# arbeitsatmosphäre: 146
# arbeitszeiten: 144
# flexible: 119
# atmosphäre: 119
# homeoffice: 114
# wertschätzung: 107
# miteinander: 103
# Processing company: Giorgio Armani
# Top 10 most frequently used words for Giorgio Armani:
# gewisse: 2
# atmosphäre: 1
# treu: 1
# bleiben: 1
# arbeitsatmosphäre: 1
# unterirdisch: 1
# führungsebene: 1
# ausgebildet: 1
# habdelt: 1
# jegliche: 1
# Processing company: Hugo Boss
# Top 10 most frequently used words for Hugo Boss:
# kantine: 28
# atmosphäre: 27
# campus: 27
# arbeitsatmosphäre: 26
# aufgaben: 25
# transparenz: 22
# work: 21
# zusammenhalt: 21
# kommuniziert: 20
# boss: 19
# ...
