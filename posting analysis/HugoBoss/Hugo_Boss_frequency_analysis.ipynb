# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import re

# Load the job descriptions CSV and classification CSV (replace with the actual file paths)
job_desc_file = 'hugo_boss_merged_output.csv'
class_file = 'classified_paragraphs.csv'

# Read the CSV files
df = pd.read_csv(job_desc_file)
classification_df = pd.read_csv(class_file)

# Clean the "Job Details" column in job description and clean classification_df column names
df['Job Details'] = df['Job Details'].str.replace('\r\n', ' ').str.strip()
classification_df.columns = classification_df.columns.str.lower().str.strip()

# Split job details into sentences/paragraphs and count the frequency
all_paragraphs = []
for details in df['Job Details']:
    paragraphs = re.split(r'[.!\n]', details)
    paragraphs = [para.strip() for para in paragraphs if para.strip()]  # Remove empty and whitespace-only strings
    all_paragraphs.extend(paragraphs)

# Count the frequency of each unique paragraph
from collections import Counter
paragraph_freq = Counter(all_paragraphs)
paragraph_freq_df = pd.DataFrame(paragraph_freq.items(), columns=['Paragraph', 'Frequency']).sort_values(by='Frequency', ascending=False)

# %%
# Filter paragraphs with frequency > 27
filtered_paragraphs_df = paragraph_freq_df[paragraph_freq_df['Frequency'] > 27]

filtered_paragraphs_df.head(20)
# Out:
#                                              Paragraph  Frequency
# 13   Unsere integrative Kultur respektiert und schä...         75
# 14   Wir setzen uns für Chancengleichheit im Einste...         73
# 85   Our inclusive culture embraces each person’s a...         46
# 86    We are committed to equal employment opportunity         46
# 87   And we believe our equitable work environment ...         46
# 81   We are committed to environmental, animal and ...         43
# 82              Does innovation drive you? Same for us         43
# 83   We have digitized most of our workflows and al...         43
# 156  Wir sind ein globales Unternehmen und unsere M...         43
# 204  Exclusive discounts for shopping and arts: ben...         42
# 70   At HUGO BOSS, we work as a team to apply our k...         42
# 71   What unites us? We love fashion, we change fas...         42
# 72   At HUGO BOSS, you have the opportunity to cont...         42
# 80   Sustainability is one of our key values, and m...         42
# 69   Our vision is to establish HUGO BOSS as the le...         42
# 207  As a fashion company, we value good taste in e...         42
# 209  We are a global company with our employees rep...         42
# 208      Welcome to our own restaurant and café, Times         42
# 206  Take advantage of the employee gym, the beach ...         42
# 205      High-performing people need a healthy balance         42

# %%
# Clean and synchronize column names for filtered_paragraphs_df
filtered_paragraphs_df.columns = filtered_paragraphs_df.columns.str.lower().str.strip()

# Merge filtered_paragraphs_df with classification_df again, ensuring all columns from classification_df are kept
merged_df = pd.merge(filtered_paragraphs_df, classification_df, on="paragraph", how="left")

# Convert all classification columns to boolean to ensure consistency
for col in classification_df.columns[1:]:
    classification_df[col] = classification_df[col].astype(bool)

# Define colors for each classification and gray for all False
colors = {

    'fashion & lifestyle': 'red',
    'health': 'green',
    'threedom of work': 'blue',
    'mobility': 'purple',
    'family': 'black',
    'grants & subsidies': 'pink',
    'times hospitality': 'yellow',
    'sustainable value': 'orange',
    'equal value': 'cyan',
    'none': 'gray'
}

# Create the matrix for the heatmap with NaN values for missing paragraphs
filtered_job_paragraphs_matrix_with_nan = np.full((len(df), len(merged_df)), np.nan)

for i, details in enumerate(df['Job Details']):
    for j, paragraph in enumerate(merged_df['paragraph']):
        if paragraph in details:
            row = merged_df.iloc[j]
            class_color = colors['none']  # Default color (gray) if all False
            for class_col in classification_df.columns[1:]:
                if row[class_col]:  # Check for True values in classification columns
                    class_color = colors[class_col]
                    break
            filtered_job_paragraphs_matrix_with_nan[i, j] = list(colors.values()).index(class_color)

# Apply KMeans clustering to the job descriptions based on the paragraph occurrences
kmeans = KMeans(n_clusters=4, random_state=42)
job_clusters = kmeans.fit_predict(np.nan_to_num(filtered_job_paragraphs_matrix_with_nan))  # Convert NaN to 0 for clustering

# Add the cluster labels to the dataframe for sorting
df['Cluster'] = job_clusters

# Sort the job descriptions based on their assigned cluster
sorted_df = df.sort_values(by='Cluster').reset_index(drop=True)

# Recreate the matrix for the heatmap, sorted by clusters
sorted_job_paragraphs_matrix_with_nan = np.full((len(sorted_df), len(merged_df)), np.nan)

for i, details in enumerate(sorted_df['Job Details']):
    for j, paragraph in enumerate(merged_df['paragraph']):
        if paragraph in details:
            row = merged_df.iloc[j]
            class_color = colors['none']  # Default color (gray) if all False
            for class_col in classification_df.columns[1:]:
                if row[class_col]:
                    class_color = colors[class_col]
                    break
            sorted_job_paragraphs_matrix_with_nan[i, j] = list(colors.values()).index(class_color)

# Plot the heatmap with jobs sorted by cluster
plt.figure(figsize=(12, 10))
cmap = plt.cm.get_cmap('tab20', len(colors))
cmap.set_bad(color='white')  # Set white for missing values (NaN)

plt.imshow(sorted_job_paragraphs_matrix_with_nan, cmap=cmap, aspect='auto')

# Create a colorbar with class labels
class_labels_for_colorbar = list(colors.keys())

cbar = plt.colorbar(ticks=range(len(colors)))
cbar.ax.set_yticklabels(class_labels_for_colorbar)

# Add cluster labels to the y-axis
#ytick_labels = [f'Cluster {cluster}' for cluster in sorted_df['Cluster']]
#plt.yticks(ticks=np.arange(len(ytick_labels)), labels=ytick_labels, fontsize=8)

# Label the axes
plt.xlabel('Filtered Paragraphs (> 27 times)')
plt.ylabel('Job Descriptions (Sorted by Cluster)')
plt.title('Job Descriptions Sorted by KMeans Clustering (4 Clusters)')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\WANG-\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\WANG-\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\WANG-\AppData\Local\Temp\ipykernel_48068\710084224.py:66: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('tab20', len(colors))

# %%
df.loc[df['Cluster']==0]
# Out:
#                                              Job Title  \
# 22   Mitarbeiter Lagerlogistik Vollzeit | Befristet...
# 23   Aushilfe Lagerlogistik Vollzeit | Befristet | ...
# 27   Mechatroniker / Servicetechniker Filderstadt (...
# 28   Aushilfe Lagerlogistik Vollzeit | Befristet | ...
# 36   Ausbildung Industriekaufmann/-Frau Mit Schwerp...
# 40        Aushilfe Küche & Service | Befristet (M/W/D)
# 43                  Duales Studium Informatik (B. Sc.)
# 44   Ausbildung Zum/R Kaufmann/-Frau Im E-Commerce ...
# 45   Ausbildung Zum/R Sport- Und Fitnesskaufmann/-F...
# 46   Ausbildung Zum Kaufmann Im Einzelhandel Ausbil...
# 47                 Praktikum IT Testmanagement (M/W/D)
# 48              Praktikum Projektmanagement IT (M/W/D)
# 51                Logistikplaner - Talent Pool (M/W/D)
# 55   Ausbildung Fachinformatiker Mit Schwerpunkt Sy...
# 57                              Kältetechniker (M/W/D)
# 58                               Referendariat (M/W/D)
# 59   Chef De Rang / Servicefachkraft Als Supervisor...
# 60   Ausbildung Zum Kaufmann Im Einzelhandel Ausbil...
# 61   Team Leader Depot Business (W/M/D) Concession ...
# 64   Praktikum Visual Merchandising Wholesale DACH ...
# 65                  Zoll Experte - Talent Pool (M/W/D)
# 66       Projektmanager Logistik - Talent Pool (M/W/D)
# 76   Techniker / Meister Der Elektrotechnik (M/W/D)...
# 77                         Area Manager Retail (W/M/D)
# 82                 IT-Controller (M/W/D) - Talent Pool
# 89                INITIATIVBEWERBUNG WHOLESALE (W/M/D)
# 90        Gruppenleiter Logistik - Talent Pool (M/W/D)
# 91   Ausbildung Fachinformatiker Mit Schwerpunkt An...
# 92                 Ausbildung Zum Fachlagerist (M/W/D)
# 93   Logistics Project Manager (M/W/D) - Schwerpunk...
# 94                                Servicekraft (M/W/D)
# 95   Aushilfe Lagerlogistik Vollzeit | Befristet | ...
# 99                      STOCK SALES SPECIALIST (W/M/D)
# 102      Sachbearbeiter Logistik - Talent Pool (M/W/D)
# 106                  PRAKTIKUM WHOLESALES HUGO (W/M/D)
# 107                                       Koch (M/W/D)
#
#                                               Job Info  \
# 22   HUGO BOSS AG\r\nGermany\r\nWendlingen\r\nCateg...
# 23   HUGO BOSS AG\r\nGermany\r\nWendlingen\r\nCateg...
# 27   HUGO BOSS AG\r\nGermany\r\nFilderstadt\r\nCate...
# 28   HUGO BOSS AG\r\nGermany\r\nFilderstadt\r\nCate...
# 36   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 40   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 43   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 44   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 45   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 46   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 47   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 48   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 51   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 55   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 57   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 58   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 59   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 60   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 61   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 64   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 65   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 66   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 76   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 77   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 82   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 89   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 90   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 91   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 92   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 93   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 94   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 95   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 99   HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 102                                                NaN
# 106  HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
# 107  HUGO BOSS AG\r\nGermany\r\nMetzingen\r\nCatego...
#
#                                            Job Details  Cluster
# 22   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 23   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 27   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 28   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 36   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 40   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 43   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 44   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 45   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 46   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 47   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 48   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 51   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 55   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 57   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 58   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 59   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 60   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 61   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 64   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 65   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 66   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 76   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 77   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 82   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 89   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 90   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 91   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 92   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 93   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 94   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 95   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 99   Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 102  Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 106  Unsere Vision ist es, HUGO BOSS als die weltwe...        0
# 107  Unsere Vision ist es, HUGO BOSS als die weltwe...        0

# %%
# Find the unique clusters from the Hugo Boss data
unique_clusters = sorted_df['Cluster'].unique()

# Create a dictionary to store the list of indices for each cluster
cluster_indices_dict = {}

for cluster in unique_clusters:
    cluster_indices = sorted_df[sorted_df['Cluster'] == cluster].index.tolist()
    cluster_indices_dict[cluster] = cluster_indices

# Output the cluster indices dictionary
cluster_indices_dict

cluster_titles_dict = {}

for cluster, indices in cluster_indices_dict.items():
    cluster_titles = sorted_df.loc[indices, 'Job Title'].tolist()
    cluster_titles_dict[cluster] = cluster_titles

# Output the job titles for each cluster
cluster_titles_dict

# Perform word frequency analysis for each cluster's job titles
cluster_word_freq_dict = {}

for cluster, titles in cluster_titles_dict.items():
    # Combine all job titles for the cluster into one text
    all_titles_text = ' '.join(titles)
    words = re.findall(r'\w+', all_titles_text.lower())  # Extract all words and convert to lowercase
    
    # Count the frequency of each word
    word_freq = Counter(words)
    
    # Convert to DataFrame for easier visualization and analysis
    word_freq_df = pd.DataFrame(word_freq.items(), columns=['Word', 'Frequency']).sort_values(by='Frequency', ascending=False)
    
    # Store the word frequency DataFrame for each cluster
    cluster_word_freq_dict[cluster] = word_freq_df

# Display the top 10 most frequent words for each cluster
for cluster, word_freq_df in cluster_word_freq_dict.items():
    print(f"Cluster {cluster} - Top 20 Most Frequent Words:")
    print(word_freq_df.head(20))
    print("\n")
# Out:
# Cluster 0 - Top 20 Most Frequent Words:
#              Word  Frequency
# 6               m         35
# 7               w         35
# 8               d         35
# 9      ausbildung          8
# 46         talent          6
# 47           pool          6
# 29            zum          5
# 18      befristet          5
# 81       vollzeit          4
# 15       aushilfe          4
# 13    schwerpunkt          4
# 41      praktikum          4
# 80  lagerlogistik          4
# 12            mit          3
# 32             im          3
# 42             it          3
# 68       logistik          3
# 31       kaufmann          3
# 11           frau          3
# 36      wholesale          2
#
#
# Cluster 1 - Top 20 Most Frequent Words:
#           Word  Frequency
# 7            m         38
# 9            d         38
# 8            f         37
# 0   internship         22
# 1       global         12
# 10        boss         12
# 17      design          8
# 2    marketing          7
# 31  management          7
# 49          it          6
# 25    menswear          5
# 62    customer          4
# 57      talent          4
# 37       black          4
# 30     product          4
# 26       camel          4
# 58        pool          4
# 21     manager          3
# 5          and          3
# 23    designer          3
#
#
# Cluster 2 - Top 20 Most Frequent Words:
#              Word  Frequency
# 4               w         37
# 5               m         37
# 6               d         37
# 2            boss         26
# 3          outlet         18
# 10          store         15
# 1           sales         13
# 7            hugo         11
# 0        aushilfe          9
# 13             im          8
# 14        verkauf          8
# 15      verkäufer          7
# 16      associate          7
# 11        manager          4
# 21    coordinator          4
# 12    werkstudent          4
# 20     operations          3
# 25  samstagskraft          2
# 23           shop          2
# 22      stockroom          2
#
#
# Cluster 3 - Top 20 Most Frequent Words:
#           Word  Frequency
# 3            m          3
# 4            f          3
# 5            d          3
# 6           at          3
# 7   eightyards          3
# 8         gmbh          3
# 2      manager          2
# 0        sales          1
# 1      product          1
# 9       supply          1
# 10       chain          1
# 11   assistant          1
# 12          to          1
# 13    director          1
